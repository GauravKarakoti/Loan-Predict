# %%
import pandas as pd
loan=pd.read_csv("loan_approval_dataset.csv")
loan
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
loan.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
loan[" loan_status"].value_counts()
# Out:
#  loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64

# %%
loan_shuffled=loan.sample(n=len(loan),random_state=1)
loan_shuffled
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 2740     2741                  2       Graduate            Yes        9400000
# 1123     1124                  0   Not Graduate             No        9100000
# 3626     3627                  3   Not Graduate             No        6900000
# 1808     1809                  1   Not Graduate            Yes        7800000
# 1143     1144                  1       Graduate            Yes         200000
# ...       ...                ...            ...            ...            ...
# 2895     2896                  1       Graduate             No        2500000
# 2763     2764                  3   Not Graduate            Yes        4600000
# 905       906                  5   Not Graduate             No        9700000
# 3980     3981                  1   Not Graduate            Yes         400000
# 235       236                  1       Graduate            Yes        6900000
#
# ...

# %%
pd.get_dummies(loan_shuffled[" loan_status"].head())
# Out:
#       Approved  Rejected
# 2740     False      True
# 1123     False      True
# 3626     False      True
# 1808      True     False
# 1143      True     False

# %%
loan_shuffled.drop(" loan_status",axis=1).head()
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 2740     2741                  2       Graduate            Yes        9400000
# 1123     1124                  0   Not Graduate             No        9100000
# 3626     3627                  3   Not Graduate             No        6900000
# 1808     1809                  1   Not Graduate            Yes        7800000
# 1143     1144                  1       Graduate            Yes         200000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 2740      37300000          14           383                    7800000
# 1123      18300000          14           458                    6100000
# 3626      18500000           6           360                   14000000
# 1808      22200000          10           763                   11200000
# 1143        400000           8           569                     200000
#
# ...

# %%
loan_final=pd.concat([loan_shuffled.drop(" loan_status",axis=1),pd.get_dummies(loan_shuffled[" loan_status"])],axis=1)
loan_final
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 2740     2741                  2       Graduate            Yes        9400000
# 1123     1124                  0   Not Graduate             No        9100000
# 3626     3627                  3   Not Graduate             No        6900000
# 1808     1809                  1   Not Graduate            Yes        7800000
# 1143     1144                  1       Graduate            Yes         200000
# ...       ...                ...            ...            ...            ...
# 2895     2896                  1       Graduate             No        2500000
# 2763     2764                  3   Not Graduate            Yes        4600000
# 905       906                  5   Not Graduate             No        9700000
# 3980     3981                  1   Not Graduate            Yes         400000
# 235       236                  1       Graduate            Yes        6900000
#
# ...

# %%
loan_final=loan_final[['loan_id',' no_of_dependents'," income_annum"," loan_amount"," loan_term"," cibil_score"," residential_assets_value"," commercial_assets_value"," luxury_assets_value"," bank_asset_value"," Approved"," Rejected"]]
loan_final
# Out:
#       loan_id   no_of_dependents   income_annum   loan_amount   loan_term  \
# 2740     2741                  2        9400000      37300000          14
# 1123     1124                  0        9100000      18300000          14
# 3626     3627                  3        6900000      18500000           6
# 1808     1809                  1        7800000      22200000          10
# 1143     1144                  1         200000        400000           8
# ...       ...                ...            ...           ...         ...
# 2895     2896                  1        2500000       5900000          12
# 2763     2764                  3        4600000      13600000          20
# 905       906                  5        9700000      37000000          14
# 3980     3981                  1         400000        900000           8
# 235       236                  1        6900000      23400000           4
#
#        cibil_score   residential_assets_value   commercial_assets_value  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=' income_annum',y=" loan_amount",data=loan_final)
plt.title("Income Annum v/s Loan Amount")
plt.xlabel("Income Annum")
plt.ylabel("Loan Ammount")
plt.show()

# %%
loan_final=loan_final.dropna()
len(loan_final)
# Out:
# 4269

# %%
train_pd,test_pd,val_pd=loan_final[:3500],loan_final[3500:4000],loan_final[4000:]
len(train_pd),len(test_pd),len(val_pd)
# Out:
# (3500, 500, 269)

# %%
'''x_train,y_train=train_pd.to_numpy()[:,:-1],train_pd.to_numpy()[:,-1]
x_val,y_val=val_pd.to_numpy()[:,:-1],val_pd.to_numpy()[:,-1]
x_test,y_test=test_pd.to_numpy()[:,:-1],test_pd.to_numpy()[:,-1]
x_train.shape,y_train.shape,x_val.shape,y_val.shape,x_test.shape,y_test.shape'''

# alternative below
# Out:
# ((3500, 11), (3500,), (269, 11), (269,), (500, 11), (500,))

# %%
from sklearn.model_selection import train_test_split
x=loan_final.drop(columns=[" loan_amount"])
y=loan_final[" loan_amount"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
'''from sklearn.preprocessing import StandardScaler
import numpy as np
scaler=StandardScaler().fit(x_train[:,:8])
def preprocessor(x):
  a=np.copy(x)
  a[:,:8]=scaler.transform(a[:,:8])
  return a
x_train,x_val,x_test=preprocessor(x_train),preprocessor(x_val),preprocessor(x_test)'''

# alternative below

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
x_train.shape,x_val.shape,x_test.shape
# Out:
# ((3500, 11), (269, 11), (500, 11))

# %%
pd.DataFrame(x_train).head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.485929 -0.295572   1.53592  2.433171  0.548366 -1.268726  0.036429
# 1 -0.831782 -1.474494  1.428988  0.336292  0.548366 -0.832468 -0.223344
# 2  1.207941  0.293888   0.64482  0.358364 -0.857186 -1.402512  0.983836
# 3 -0.273568 -0.885033  0.965616  0.766704  -0.15441   0.94165  0.555975
# 4 -0.815484 -0.885033 -1.743328 -1.639189 -0.505798 -0.186805 -1.124908
#
#          7         8         9      10
# 0  2.493009  27100000   7700000  False
# 1  0.961853  34100000  10000000  False
# 2  -1.14063  18800000   9600000  False
# 3 -0.820687  27000000   4900000   True
# 4 -1.094923    700000    300000   True

# %%
pd.DataFrame(x_train)[0].hist()
# Out:
# <Axes: >

# %%
'''from sklearn.metrics import mean_squared_error as mse
from sklearn.linear_model import LinearRegression
lm=LinearRegression().fit(x_train,y_train)
mse(lm.predict(x_train),y_train,squared=False),mse(lm.predict(x_val),y_val,squared=False)'''

# alternative below
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# (3.416389119646916e-13, 3.1890023798695737e-13)

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.linear_model import LinearRegression
lm=LinearRegression().fit(x_train,y_train)
train_score=lm.score(x_train,y_train)
train_score
# Out:
# 0.8600623597071928

# %%
plt.figure(figsize=(8,6))
plt.plot([min(y_test),max(y_test)],[min(y_test),max(y_test)],'r--')
plt.title("Actual v/s Precited Loan Value (Gradient Boosting)")
plt.xlabel("Actual Loan Value")
plt.ylabel("Predicted Loan Value")
plt.show()

# %%
'''from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor(n_neighbors=10).fit(x_train,y_train)
mse(knn.predict(x_train),y_train,squared=False),mse(knn.predict(x_val),y_val,squared=False)'''

# alternative below
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# (0.4495680466530385, 0.5099019513592785)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor(n_neighbors=10).fit(x_train,y_train)
train_score=knn.score(x_train,y_train)
train_score
# Out:
# 0.8526468035250222

# %%
'''from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(max_depth=10).fit(x_train,y_train)
mse(rfr.predict(x_train),y_train,squared=False),mse(rfr.predict(x_val),y_val,squared=False)'''

# alternative below
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# (0.0, 0.0)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(max_depth=10).fit(x_train,y_train)
train_score=rfr.score(x_train,y_train)
train_score
# Out:
# Running cells with 'Python 3.13.0' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/karak/AppData/Local/Programs/Python/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'
